# %% [markdown]
# Basic Sentiment Analysis

# %%
from transformers import pipeline

# Load the sentiment analysis pipeline
sentiment_analysis = pipeline("sentiment-analysis")

# Sample text for sentiment analysis
text = "Hockey is a boring sport that I really hate"

# Perform sentiment analysis
results = sentiment_analysis(text)

# Display the sentiment analysis results
for result in results:
    print(f"Sentiment: {result['label']}, Score: {result['score']}")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use mps:0
# Sentiment: NEGATIVE, Score: 0.9995912909507751

# %% [markdown]
# Multiple Prediction Example

# %%
from transformers import pipeline

# Load the sentiment analysis pipeline
sentiment_analysis = pipeline("sentiment-analysis")

# Sample text for sentiment analysis
text = ["It's fun to learn about AI", \
        "I'm tired today", \
        "The movie was okay, but not the best",\
        "This is awesome"]

# Perform sentiment analysis
results = sentiment_analysis(text)

# Display the sentiment analysis results
for result in results:
    print(f"Sentiment: {result['label']}, Score: {result['score']}")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use mps:0
# Sentiment: POSITIVE, Score: 0.9998530149459839
# Sentiment: NEGATIVE, Score: 0.999762237071991
# Sentiment: NEGATIVE, Score: 0.9925425052642822
# Sentiment: POSITIVE, Score: 0.9998669624328613

# %% [markdown]
# Emotional Probability Distribution

# %%
from transformers import pipeline

classifier = pipeline(task="text-classification", model="SamLowe/roberta-base-go_emotions", top_k=None)

sentences = ["I find the olympics really boring I wish they would put something else on TV in the summer"]

model_outputs = classifier(sentences)

# Print each output on a new line with a carriage return after each line
for output in model_outputs[0]:
    print(f"Label: {output['label']}, Score: {output['score']}\n")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/380 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# Device set to use mps:0
# Label: desire, Score: 0.4668136537075043
#
# Label: disappointment, Score: 0.3308492600917816
#
# Label: annoyance, Score: 0.18453361093997955
#
# Label: disapproval, Score: 0.07362997531890869
#
# Label: neutral, Score: 0.05550166592001915
#
# Label: sadness, Score: 0.02860000915825367
#
# Label: disgust, Score: 0.02737627923488617
#
# Label: optimism, Score: 0.023101501166820526
#
# Label: anger, Score: 0.01867983117699623
#
# Label: realization, Score: 0.012172544375061989
#
# Label: approval, Score: 0.006305180490016937
#
# Label: love, Score: 0.005806406494230032
#
# Label: confusion, Score: 0.0045568379573524
#
# Label: amusement, Score: 0.004552145022898912
#
# Label: curiosity, Score: 0.00451058242470026
#
# Label: embarrassment, Score: 0.004485524259507656
#
# Label: admiration, Score: 0.004485185723751783
#
# Label: remorse, Score: 0.004312369506806135
#
# Label: excitement, Score: 0.0037685506977140903
#
# Label: joy, Score: 0.0036490855272859335
#
# Label: nervousness, Score: 0.003388430457562208
#
# Label: surprise, Score: 0.0033880409318953753
#
# Label: caring, Score: 0.002424346748739481
#
# Label: fear, Score: 0.0021225016098469496
#
# Label: grief, Score: 0.0017208362696692348
#
# Label: gratitude, Score: 0.0013063392834737897
#
# Label: relief, Score: 0.0012121039908379316
#
# Label: pride, Score: 0.0009242059895768762
